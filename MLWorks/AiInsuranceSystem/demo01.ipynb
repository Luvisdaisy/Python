# %% [markdown]
# # Day1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
x=list(range(1,8))
y=[ random.randint(10,30) for i in x]
plt.title('测试')
plt.plot(x,y)
plt.show()

# %%
s='asdasdsad'
while(len(s)):
  print(s)
# Out:
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# asdasdsad
# ...
